# %%
import pandas as pd

import numpy as np

import matplotlib as mlp

import matplotlib.pyplot as plt

import seaborn as sns

df1 = pd.read_csv("2008-2009-H.csv")

# %%
df2 = pd.read_csv("2009-2010-H.csv")

# %%
df3 = pd.read_csv("2010-2011-H.csv")

# %%
df4 = pd.read_csv("2011-2012-H.csv")

# %%
df5 = pd.read_csv("2012-2013-H.csv")

# %%
df6 = pd.read_csv("2013-2014-H.csv")

# %%
df7 = pd.read_csv("2014-2015-H.csv")

# %%
df8 = pd.read_csv("2015-2016-H.csv")
df9 = pd.read_csv("2016-2017-H.csv")
df10 = pd.read_csv("2017-2018-H.csv")
df11 = pd.read_csv("2018-2019-H.csv")
df12 = pd.read_csv("2019-2020-H.csv")
df13 = pd.read_csv("2020-2021-H.csv")
df14 = pd.read_csv("2021-2022-H.csv")

# %%
df1.drop("HART", axis=1)
# Out:
#       playerId  season              name team position situation  \
# 0      8462196    2008  Stephane Robidas  DAL        D     other
# 1      8462196    2008  Stephane Robidas  DAL        D       all
# 2      8462196    2008  Stephane Robidas  DAL        D      5on5
# 3      8462196    2008  Stephane Robidas  DAL        D      4on5
# 4      8462196    2008  Stephane Robidas  DAL        D      5on4
# ...        ...     ...               ...  ...      ...       ...
# 4420   8470622    2008     Patrick Eaves  CAR        R     other
# 4421   8470622    2008     Patrick Eaves  CAR        R       all
# 4422   8470622    2008     Patrick Eaves  CAR        R      5on5
# 4423   8470622    2008     Patrick Eaves  CAR        R      4on5
# 4424   8470622    2008     Patrick Eaves  CAR        R      5on4
#
#       games_played  icetime  shifts  gameScore  ...  OffIce_F_xGoals  \
# 0               72     6729     105      31.93  ...             6.79
# ...

# %%
names = ["Alex Ovechkin", "Evgeni Malkin", "Pavel Datsyuk"]

df1.loc[df1['name'].isin(names), 'HART'] = 1 
df1.loc[~df1['name'].isin(names), 'HART'] = 0

# %%
df1
# Out:
#       playerId  season              name team position situation  \
# 0      8462196    2008  Stephane Robidas  DAL        D     other
# 1      8462196    2008  Stephane Robidas  DAL        D       all
# 2      8462196    2008  Stephane Robidas  DAL        D      5on5
# 3      8462196    2008  Stephane Robidas  DAL        D      4on5
# 4      8462196    2008  Stephane Robidas  DAL        D      5on4
# ...        ...     ...               ...  ...      ...       ...
# 4420   8470622    2008     Patrick Eaves  CAR        R     other
# 4421   8470622    2008     Patrick Eaves  CAR        R       all
# 4422   8470622    2008     Patrick Eaves  CAR        R      5on5
# 4423   8470622    2008     Patrick Eaves  CAR        R      4on5
# 4424   8470622    2008     Patrick Eaves  CAR        R      5on4
#
#       games_played  icetime  shifts  gameScore  ...  OffIce_A_xGoals  \
# 0               72     6729     105      31.93  ...            12.11
# ...

# %%
df1.loc[df1['name'].isin(names)]
# Out:
#       playerId  season           name team position situation  games_played  \
# 1115   8471214    2008  Alex Ovechkin  WSH        L     other            79
# 1116   8471214    2008  Alex Ovechkin  WSH        L       all            79
# 1117   8471214    2008  Alex Ovechkin  WSH        L      5on5            79
# 1118   8471214    2008  Alex Ovechkin  WSH        L      4on5            79
# 1119   8471214    2008  Alex Ovechkin  WSH        L      5on4            79
# 2570   8467514    2008  Pavel Datsyuk  DET        C     other            80
# 2571   8467514    2008  Pavel Datsyuk  DET        C       all            80
# 2572   8467514    2008  Pavel Datsyuk  DET        C      5on5            80
# 2573   8467514    2008  Pavel Datsyuk  DET        C      4on5            80
# 2574   8467514    2008  Pavel Datsyuk  DET        C      5on4            80
# 3410   8471215    2008  Evgeni Malkin  PIT        C     other            82
# ...

# %%
df1
# Out:
#       playerId  season              name team position situation  \
# 0      8462196    2008  Stephane Robidas  DAL        D     other
# 1      8462196    2008  Stephane Robidas  DAL        D       all
# 2      8462196    2008  Stephane Robidas  DAL        D      5on5
# 3      8462196    2008  Stephane Robidas  DAL        D      4on5
# 4      8462196    2008  Stephane Robidas  DAL        D      5on4
# ...        ...     ...               ...  ...      ...       ...
# 4420   8470622    2008     Patrick Eaves  CAR        R     other
# 4421   8470622    2008     Patrick Eaves  CAR        R       all
# 4422   8470622    2008     Patrick Eaves  CAR        R      5on5
# 4423   8470622    2008     Patrick Eaves  CAR        R      4on5
# 4424   8470622    2008     Patrick Eaves  CAR        R      5on4
#
#       games_played  icetime  shifts  gameScore  ...  OffIce_A_xGoals  \
# 0               72     6729     105      31.93  ...            12.11
# ...

# %%
player_id = []

df1
# Out:
#       playerId  season              name team position situation  \
# 0      8462196    2008  Stephane Robidas  DAL        D     other
# 1      8462196    2008  Stephane Robidas  DAL        D       all
# 2      8462196    2008  Stephane Robidas  DAL        D      5on5
# 3      8462196    2008  Stephane Robidas  DAL        D      4on5
# 4      8462196    2008  Stephane Robidas  DAL        D      5on4
# ...        ...     ...               ...  ...      ...       ...
# 4420   8470622    2008     Patrick Eaves  CAR        R     other
# 4421   8470622    2008     Patrick Eaves  CAR        R       all
# 4422   8470622    2008     Patrick Eaves  CAR        R      5on5
# 4423   8470622    2008     Patrick Eaves  CAR        R      4on5
# 4424   8470622    2008     Patrick Eaves  CAR        R      5on4
#
#       games_played  icetime  shifts  gameScore  ...  OffIce_A_xGoals  \
# 0               72     6729     105      31.93  ...            12.11
# ...

# %%
df2
# Out:
#       playerId  season           name team position situation  games_played  \
# 0      8471707    2009     James Neal  DAL        R     other            77
# 1      8471707    2009     James Neal  DAL        R       all            77
# 2      8471707    2009     James Neal  DAL        R      5on5            77
# 3      8471707    2009     James Neal  DAL        R      4on5            77
# 4      8471707    2009     James Neal  DAL        R      5on4            77
# ...        ...     ...            ...  ...      ...       ...           ...
# 4390   8471675    2009  Sidney Crosby  PIT        C     other            80
# 4391   8471675    2009  Sidney Crosby  PIT        C       all            80
# 4392   8471675    2009  Sidney Crosby  PIT        C      5on5            80
# 4393   8471675    2009  Sidney Crosby  PIT        C      4on5            80
# 4394   8471675    2009  Sidney Crosby  PIT        C      5on4            80
#
# ...

# %%
names = ["Alex Ovechkin", "Henrik Sedin", "Sidney Crosby"]

df2.loc[df2['name'].isin(names), 'HART'] = 1 
df2.loc[~df2['name'].isin(names), 'HART'] = 0

# %%
df2["HART"] = df2["HART"].astype(int)

# %%
df3
# Out:
#       playerId  season           name team position situation  games_played  \
# 0      8470144    2010  Frans Nielsen  NYI        C     other            71
# 1      8470144    2010  Frans Nielsen  NYI        C       all            71
# 2      8470144    2010  Frans Nielsen  NYI        C      5on5            71
# 3      8470144    2010  Frans Nielsen  NYI        C      4on5            71
# 4      8470144    2010  Frans Nielsen  NYI        C      5on4            71
# ...        ...     ...            ...  ...      ...       ...           ...
# 4450   8462077    2010   Jochen Hecht  BUF        C     other            67
# 4451   8462077    2010   Jochen Hecht  BUF        C       all            67
# 4452   8462077    2010   Jochen Hecht  BUF        C      5on5            67
# 4453   8462077    2010   Jochen Hecht  BUF        C      4on5            67
# 4454   8462077    2010   Jochen Hecht  BUF        C      5on4            67
#
# ...

# %%
df4.loc[df4['name'].isin(names), 'HART'] = 1 
df4.loc[~df4['name'].isin(names), 'HART'] = 0

# %%
df4["HART"] = df4["HART"].astype(int)

# %%
df4[df4['HART'] == 1]
# Out:
#      playerId  season            name team position situation  games_played  \
# 200   8471215    2011   Evgeni Malkin  PIT        C     other            75
# 201   8471215    2011   Evgeni Malkin  PIT        C       all            75
# 202   8471215    2011   Evgeni Malkin  PIT        C      5on5            75
# 203   8471215    2011   Evgeni Malkin  PIT        C      4on5            75
# 204   8471215    2011   Evgeni Malkin  PIT        C      5on4            75
# 875   8474564    2011  Steven Stamkos  T.B        C     other            82
# 876   8474564    2011  Steven Stamkos  T.B        C       all            82
# 877   8474564    2011  Steven Stamkos  T.B        C      5on5            82
# 878   8474564    2011  Steven Stamkos  T.B        C      4on5            82
# 879   8474564    2011  Steven Stamkos  T.B        C      5on4            82
#
#      icetime  shifts  gameScore  ...  OffIce_A_xGoals  OffIce_F_shotAttempts  \
# ...

# %%
df5
# Out:
#       playerId  season           name team position situation  games_played  \
# 0      8475793    2012  Ryan Johansen  CBJ        C     other            40
# 1      8475793    2012  Ryan Johansen  CBJ        C       all            40
# 2      8475793    2012  Ryan Johansen  CBJ        C      5on5            40
# 3      8475793    2012  Ryan Johansen  CBJ        C      4on5            40
# 4      8475793    2012  Ryan Johansen  CBJ        C      5on4            40
# ...        ...     ...            ...  ...      ...       ...           ...
# 4190   8473446    2012   Erik Johnson  COL        D     other            31
# 4191   8473446    2012   Erik Johnson  COL        D       all            31
# 4192   8473446    2012   Erik Johnson  COL        D      5on5            31
# 4193   8473446    2012   Erik Johnson  COL        D      4on5            31
# 4194   8473446    2012   Erik Johnson  COL        D      5on4            31
#
# ...

# %%
df6["HART"] = df6["HART"].astype(int)

# %%
df7
# Out:
#       playerId  season              name team position situation  \
# 0      8475793    2014     Ryan Johansen  CBJ        C     other
# 1      8475793    2014     Ryan Johansen  CBJ        C       all
# 2      8475793    2014     Ryan Johansen  CBJ        C      5on5
# 3      8475793    2014     Ryan Johansen  CBJ        C      4on5
# 4      8475793    2014     Ryan Johansen  CBJ        C      5on4
# ...        ...     ...               ...  ...      ...       ...
# 4405   8468535    2014  Antoine Vermette  CHI        C     other
# 4406   8468535    2014  Antoine Vermette  CHI        C       all
# 4407   8468535    2014  Antoine Vermette  CHI        C      5on5
# 4408   8468535    2014  Antoine Vermette  CHI        C      4on5
# 4409   8468535    2014  Antoine Vermette  CHI        C      5on4
#
#       games_played  icetime  shifts  gameScore  ...  OffIce_F_xGoals  \
# 0               82     5202      94      53.11  ...             8.99
# ...

# %%
names = ["Carey Price", "Alex Ovechkin", "John Tavares"]

df7.loc[df7['name'].isin(names), 'HART'] = 1 
df7.loc[~df7['name'].isin(names), 'HART'] = 0

# %%
df7["HART"] = df7["HART"].astype(int)

# %%
names = ["Patrick Kane", "Sidney Crosby", "Jamie Benn"]

df8.loc[df8['name'].isin(names), 'HART'] = 1 
df8.loc[~df8['name'].isin(names), 'HART'] = 0

# %%
df8["HART"] = df8["HART"].astype(int)

# %%
names = ["Connor McDavid", "Sidney Crosby", "Sergei Bobrovsky"]

df9.loc[df9['name'].isin(names), 'HART'] = 1 
df9.loc[~df9['name'].isin(names), 'HART'] = 0

# %%
df9["HART"] = df9["HART"].astype(int)

# %%
names = ["Taylor Hall", "Nathan MacKinnon", "Anze Kopitar"]

df10.loc[df10['name'].isin(names), 'HART'] = 1 
df10.loc[~df10['name'].isin(names), 'HART'] = 0

# %%
df10["HART"] = df10["HART"].astype(int)

# %%
names = ["Nikita Kucherov", "Sidney Crosby", "Connor McDavid"]

df11.loc[df11['name'].isin(names), 'HART'] = 1 
df11.loc[~df11['name'].isin(names), 'HART'] = 0

# %%
df11["HART"] = df11["HART"].astype(int)

# %%
names = ["Leon Draisaitl", "Nathan MacKinnon", "Artemi Panarin"]

df12.loc[df12['name'].isin(names), 'HART'] = 1 
df12.loc[~df12['name'].isin(names), 'HART'] = 0

# %%
df12["HART"] = df12["HART"].astype(int)

# %%
names = ["Connor McDavid", "Auston Matthews", "Nathan MacKinnon"]

df13.loc[df13['name'].isin(names), 'HART'] = 1 
df13.loc[~df13['name'].isin(names), 'HART'] = 0

# %%
df13["HART"] = df13["HART"].astype(int)

# %%
names = ["Connor McDavid", "Auston Matthews", "Igor Shesterkin"]

df14.loc[df14['name'].isin(names), 'HART'] = 1 
df14.loc[~df14['name'].isin(names), 'HART'] = 0

# %%
df14["HART"] = df14["HART"].astype(int)

# %%
final_set = df1.append(df2)

# %%
added_dfs = [df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14]

# %%
final_set2 = df1.append(added_dfs)

# %%
final_set2.to_csv("final_set.csv")
